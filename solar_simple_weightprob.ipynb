# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from ens_util import *
from math import isnan
from sklearn.calibration import calibration_curve
plt.rcParams['figure.figsize'] = [9,9]

# %%
data_files = glob('data_crop*.nc')
res_files = glob('2014*Z_crs_gauss.nc')

def lcc(lats, lons, R=6370, truelat0=31.7, truelat1=31.7,
                  ref_lat=31.68858, stand_lon=-113.7):
    """
    Taken from Tony Lorenzo's repository at:
    https://github.com/alorenzo175/
         satellite_irradiance_optimal_interpolation.git.
    Convert from spherical lats/lons like what comes out of WRF to the WRF
    Lambert Conformal x/y coordinates. Defaults are what
    are generally used for the AZ domain
    """
    phis = np.radians(lats)
    lambdas = np.radians(lons)
    phi0 = np.radians(ref_lat)
    phi1 = np.radians(truelat0)
    phi2 = np.radians(truelat1)
    lambda0 = np.radians(stand_lon)

    if truelat0 == truelat1:
        n = np.sin(phi0)
    else:
        n = (np.log(np.cos(phi1) / np.cos(phi2)) /
             np.log(np.tan(np.pi / 4 + phi2 / 2) /
                    np.tan(np.pi / 4 + phi1 / 2)
                    ))
    F = (np.cos(phi1) * np.power(np.tan(np.pi / 4 + phi1 / 2), n) / n)
    rho0 = F / np.power(np.tan(np.pi / 4 + phi0 / 2), n)
    rho = F / np.power(np.tan(np.pi / 4 + phis / 2), n)
    x = R * rho * np.sin(n * (lambdas - lambda0))
    y = R * (rho0 - rho * np.cos(n * (lambdas - lambda0)))

    return round(x,1),round(y,1)

# %%
#print(lcc(32.37,-111.24))
#print(lcc(32.37,-111.28))
print(lcc(32.381,-111.054))
print(lcc(32.271,-110.877))

lat = [32.370522,32.372169,32.105007,32.103264,32.117565,32.101406,32.099697,
       32.107296,32.142822,35.022871,32.191449,34.297182,35.239405,32.033751,
       31.555180,32.236389,32.033751,31.496393,35.303131,32.101040,35.342665]
long = [-111.241783,-111.282875,-110.822395,-110.818794,
        -110.819511,-110.815613,-110.811325,-110.824539,
        -110.877073,-114.162059,-110.862375,-109.266867,
        -114.039004,-110.962391,-110.319957,-110.141944,
        -110.962391,-111.006983,-114.013827,-110.821436,-113.907816]
#lat = []
#long =
# Out:
# (248.4, 80.0)
# (265.4, 68.2)

# %%
for i in range(len(lat)):
    x,y = lcc(lat[i],long[i])
    if(y>32 and y<88 and x>240 and x<280):
        print(x,y,i+1)
    else:
        print(x,y,'out',i+1)
# Include first two at x=240, collapse into single point.
# Out:
# 230.8 78.4 out 1
# 227.0 78.5 out 2
# 271.0 49.9 3
# 271.3 49.7 4
# 271.2 51.3 5
# 271.6 49.5 6
# 272.0 49.3 7
# 270.8 50.1 8
# 265.7 53.9 9
# -42.1 371.0 out 10
# 267.0 59.4 11
# 407.5 298.4 out 12
# -30.8 395.1 out 13
# 258.0 41.6 14
# 320.2 -9.9 out 15
# 334.6 66.4 out 16
# 258.0 41.6 17
# 255.3 -18.2 out 18
# -28.5 402.2 out 19
# 271.1 49.4 20
# -18.9 406.5 out 21

# %%
coordx = [240,258,266,267,271,271,271,272]
coordy = [78,42,54,59,49,50,51,49]
for x in range(248,266):
    for y in range(68,81):
        coordx.append(x)
        coordy.append(y)

#weights = np.array([59,49.87,13,2.5,2.04,13.7,5,8])
weights = np.array(len(coordx)*[1])
thresh = 0.2
data = build_datadf(data_files,coordx,coordy)
(fr15,fr30,fr45,fr60) = build_solar_fractions_weightprob(res_files,data.index,weights,data.columns,coordx,coordy,thresh)
# Out:
# solar fractions
# 20140402_1630Z_crs_gauss.nc
# 20140402_1645Z_crs_gauss.nc
# 20140402_1700Z_crs_gauss.nc
# 20140402_1715Z_crs_gauss.nc
# 20140402_1730Z_crs_gauss.nc
# 20140402_1745Z_crs_gauss.nc
# 20140402_1800Z_crs_gauss.nc
# 20140402_1830Z_crs_gauss.nc
# 20140402_1845Z_crs_gauss.nc
# 20140402_1900Z_crs_gauss.nc
# 20140402_1915Z_crs_gauss.nc
# 20140402_1930Z_crs_gauss.nc
# 20140402_1945Z_crs_gauss.nc
# 20140402_2000Z_crs_gauss.nc
# 20140402_2015Z_crs_gauss.nc
# 20140402_2030Z_crs_gauss.nc
# 20140402_2100Z_crs_gauss.nc
# 20140402_2130Z_crs_gauss.nc
# 20140402_2145Z_crs_gauss.nc
# 20140402_2200Z_crs_gauss.nc
# 20140402_2215Z_crs_gauss.nc
# 20140402_2230Z_crs_gauss.nc
# 20140405_1630Z_crs_gauss.nc
# 20140405_1645Z_crs_gauss.nc
# 20140405_1700Z_crs_gauss.nc
# 20140405_1715Z_crs_gauss.nc
# 20140405_1730Z_crs_gauss.nc
# 20140405_1745Z_crs_gauss.nc
# 20140405_1800Z_crs_gauss.nc
# 20140405_1830Z_crs_gauss.nc
# 20140405_1845Z_crs_gauss.nc
# 20140405_1900Z_crs_gauss.nc
# 20140405_1915Z_crs_gauss.nc
# 20140405_1930Z_crs_gauss.nc
# 20140405_1945Z_crs_gauss.nc
# 20140405_2000Z_crs_gauss.nc
# 20140405_2015Z_crs_gauss.nc
# 20140405_2030Z_crs_gauss.nc
# 20140405_2100Z_crs_gauss.nc
# 20140405_2130Z_crs_gauss.nc
# 20140405_2145Z_crs_gauss.nc
# 20140405_2200Z_crs_gauss.nc
# 20140405_2215Z_crs_gauss.nc
# 20140405_2230Z_crs_gauss.nc
# 20140409_1630Z_crs_gauss.nc
# 20140409_1645Z_crs_gauss.nc
# 20140409_1700Z_crs_gauss.nc
# 20140409_1715Z_crs_gauss.nc
# 20140409_1730Z_crs_gauss.nc
# 20140409_1745Z_crs_gauss.nc
# 20140409_1800Z_crs_gauss.nc
# 20140409_1830Z_crs_gauss.nc
# 20140409_1845Z_crs_gauss.nc
# 20140409_1900Z_crs_gauss.nc
# 20140409_1915Z_crs_gauss.nc
# 20140409_1930Z_crs_gauss.nc
# 20140409_1945Z_crs_gauss.nc
# 20140409_2000Z_crs_gauss.nc
# 20140409_2015Z_crs_gauss.nc
# 20140409_2030Z_crs_gauss.nc
# 20140409_2100Z_crs_gauss.nc
# 20140409_2130Z_crs_gauss.nc
# 20140409_2145Z_crs_gauss.nc
# 20140409_2200Z_crs_gauss.nc
# 20140409_2215Z_crs_gauss.nc
# 20140409_2230Z_crs_gauss.nc
# 20140410_1630Z_crs_gauss.nc
# 20140410_1645Z_crs_gauss.nc
# 20140410_1700Z_crs_gauss.nc
# 20140410_1715Z_crs_gauss.nc
# 20140410_1730Z_crs_gauss.nc
# 20140410_1745Z_crs_gauss.nc
# 20140410_1800Z_crs_gauss.nc
# 20140410_1830Z_crs_gauss.nc
# 20140410_1845Z_crs_gauss.nc
# 20140410_1900Z_crs_gauss.nc
# 20140410_1915Z_crs_gauss.nc
# 20140410_1930Z_crs_gauss.nc
# 20140410_1945Z_crs_gauss.nc
# 20140410_2015Z_crs_gauss.nc
# 20140410_2030Z_crs_gauss.nc
# 20140410_2100Z_crs_gauss.nc
# 20140410_2130Z_crs_gauss.nc
# 20140410_2145Z_crs_gauss.nc
# 20140410_2200Z_crs_gauss.nc
# 20140410_2215Z_crs_gauss.nc
# 20140410_2230Z_crs_gauss.nc
# 20140411_1630Z_crs_gauss.nc
# 20140411_1645Z_crs_gauss.nc
# 20140411_1700Z_crs_gauss.nc
# 20140411_1715Z_crs_gauss.nc
# 20140411_1730Z_crs_gauss.nc
# 20140411_1745Z_crs_gauss.nc
# 20140411_1800Z_crs_gauss.nc
# 20140411_1830Z_crs_gauss.nc
# 20140411_1845Z_crs_gauss.nc
# 20140411_1900Z_crs_gauss.nc
# 20140411_1915Z_crs_gauss.nc
# 20140411_1930Z_crs_gauss.nc
# 20140411_1945Z_crs_gauss.nc
# 20140411_2000Z_crs_gauss.nc
# 20140411_2015Z_crs_gauss.nc
# 20140411_2030Z_crs_gauss.nc
# 20140411_2100Z_crs_gauss.nc
# 20140411_2130Z_crs_gauss.nc
# 20140411_2145Z_crs_gauss.nc
# 20140411_2200Z_crs_gauss.nc
# 20140411_2215Z_crs_gauss.nc
# 20140411_2230Z_crs_gauss.nc
# 20140412_1630Z_crs_gauss.nc
# 20140412_1645Z_crs_gauss.nc
# 20140412_1700Z_crs_gauss.nc
# 20140412_1715Z_crs_gauss.nc
# 20140412_1730Z_crs_gauss.nc
# 20140412_1745Z_crs_gauss.nc
# 20140412_1800Z_crs_gauss.nc
# 20140412_1830Z_crs_gauss.nc
# 20140412_1845Z_crs_gauss.nc
# 20140412_1900Z_crs_gauss.nc
# 20140412_1915Z_crs_gauss.nc
# 20140412_1930Z_crs_gauss.nc
# 20140412_1945Z_crs_gauss.nc
# 20140412_2000Z_crs_gauss.nc
# 20140412_2015Z_crs_gauss.nc
# 20140412_2030Z_crs_gauss.nc
# 20140412_2100Z_crs_gauss.nc
# 20140412_2130Z_crs_gauss.nc
# 20140412_2145Z_crs_gauss.nc
# 20140412_2200Z_crs_gauss.nc
# 20140412_2215Z_crs_gauss.nc
# 20140412_2230Z_crs_gauss.nc
# 20140415_1630Z_crs_gauss.nc
# 20140415_1645Z_crs_gauss.nc
# 20140415_1700Z_crs_gauss.nc
# 20140415_1715Z_crs_gauss.nc
# 20140415_1730Z_crs_gauss.nc
# 20140415_1745Z_crs_gauss.nc
# 20140415_1800Z_crs_gauss.nc
# 20140415_1830Z_crs_gauss.nc
# 20140415_1845Z_crs_gauss.nc
# 20140415_1900Z_crs_gauss.nc
# 20140415_1915Z_crs_gauss.nc
# 20140415_1930Z_crs_gauss.nc
# 20140415_1945Z_crs_gauss.nc
# 20140415_2000Z_crs_gauss.nc
# 20140415_2015Z_crs_gauss.nc
# 20140415_2030Z_crs_gauss.nc
# 20140415_2100Z_crs_gauss.nc
# 20140415_2130Z_crs_gauss.nc
# 20140415_2145Z_crs_gauss.nc
# 20140415_2200Z_crs_gauss.nc
# 20140415_2215Z_crs_gauss.nc
# 20140415_2230Z_crs_gauss.nc
# 20140418_1630Z_crs_gauss.nc
# 20140418_1645Z_crs_gauss.nc
# 20140418_1700Z_crs_gauss.nc
# 20140418_1715Z_crs_gauss.nc
# 20140418_1730Z_crs_gauss.nc
# 20140418_1745Z_crs_gauss.nc
# 20140418_1800Z_crs_gauss.nc
# 20140418_1830Z_crs_gauss.nc
# 20140418_1845Z_crs_gauss.nc
# 20140418_1900Z_crs_gauss.nc
# 20140418_1915Z_crs_gauss.nc
# 20140418_1930Z_crs_gauss.nc
# 20140418_1945Z_crs_gauss.nc
# 20140418_2000Z_crs_gauss.nc
# 20140418_2015Z_crs_gauss.nc
# 20140418_2030Z_crs_gauss.nc
# 20140418_2100Z_crs_gauss.nc
# 20140418_2130Z_crs_gauss.nc
# 20140418_2145Z_crs_gauss.nc
# 20140418_2200Z_crs_gauss.nc
# 20140418_2215Z_crs_gauss.nc
# 20140418_2230Z_crs_gauss.nc
# 20140419_1630Z_crs_gauss.nc
# 20140419_1645Z_crs_gauss.nc
# 20140419_1700Z_crs_gauss.nc
# 20140419_1715Z_crs_gauss.nc
# 20140419_1730Z_crs_gauss.nc
# 20140419_1745Z_crs_gauss.nc
# 20140419_1800Z_crs_gauss.nc
# 20140419_1830Z_crs_gauss.nc
# 20140419_1845Z_crs_gauss.nc
# 20140419_1900Z_crs_gauss.nc
# 20140419_1915Z_crs_gauss.nc
# 20140419_1930Z_crs_gauss.nc
# 20140419_1945Z_crs_gauss.nc
# 20140419_2000Z_crs_gauss.nc
# 20140419_2015Z_crs_gauss.nc
# 20140419_2030Z_crs_gauss.nc
# 20140419_2100Z_crs_gauss.nc
# 20140419_2130Z_crs_gauss.nc
# 20140419_2145Z_crs_gauss.nc
# 20140419_2200Z_crs_gauss.nc
# 20140419_2215Z_crs_gauss.nc
# 20140419_2230Z_crs_gauss.nc
# 20140420_1630Z_crs_gauss.nc
# 20140420_1645Z_crs_gauss.nc
# 20140420_1700Z_crs_gauss.nc
# 20140420_1715Z_crs_gauss.nc
# 20140420_1730Z_crs_gauss.nc
# 20140420_1745Z_crs_gauss.nc
# 20140420_1800Z_crs_gauss.nc
# 20140420_1830Z_crs_gauss.nc
# 20140420_1845Z_crs_gauss.nc
# 20140420_1900Z_crs_gauss.nc
# 20140420_1915Z_crs_gauss.nc
# 20140420_1930Z_crs_gauss.nc
# 20140420_1945Z_crs_gauss.nc
# 20140420_2000Z_crs_gauss.nc
# 20140420_2015Z_crs_gauss.nc
# 20140420_2030Z_crs_gauss.nc
# 20140420_2100Z_crs_gauss.nc
# 20140420_2130Z_crs_gauss.nc
# 20140420_2145Z_crs_gauss.nc
# 20140420_2200Z_crs_gauss.nc
# 20140420_2215Z_crs_gauss.nc
# 20140420_2230Z_crs_gauss.nc
# 20140421_1630Z_crs_gauss.nc
# 20140421_1645Z_crs_gauss.nc
# 20140421_1700Z_crs_gauss.nc
# 20140421_1715Z_crs_gauss.nc
# 20140421_1730Z_crs_gauss.nc
# 20140421_1745Z_crs_gauss.nc
# 20140421_1800Z_crs_gauss.nc
# 20140421_1830Z_crs_gauss.nc
# 20140421_1845Z_crs_gauss.nc
# 20140421_1900Z_crs_gauss.nc
# 20140421_1915Z_crs_gauss.nc
# 20140421_1930Z_crs_gauss.nc
# 20140421_1945Z_crs_gauss.nc
# 20140421_2000Z_crs_gauss.nc
# 20140421_2015Z_crs_gauss.nc
# 20140421_2030Z_crs_gauss.nc
# 20140421_2100Z_crs_gauss.nc
# 20140421_2130Z_crs_gauss.nc
# 20140421_2145Z_crs_gauss.nc
# 20140421_2200Z_crs_gauss.nc
# 20140421_2215Z_crs_gauss.nc
# 20140421_2230Z_crs_gauss.nc
# 20140422_1630Z_crs_gauss.nc
# 20140422_1645Z_crs_gauss.nc
# 20140422_1700Z_crs_gauss.nc
# 20140422_1715Z_crs_gauss.nc
# 20140422_1730Z_crs_gauss.nc
# 20140422_1745Z_crs_gauss.nc
# 20140422_1800Z_crs_gauss.nc
# 20140422_1830Z_crs_gauss.nc
# 20140422_1845Z_crs_gauss.nc
# 20140422_1900Z_crs_gauss.nc
# 20140422_1915Z_crs_gauss.nc
# 20140422_1930Z_crs_gauss.nc
# 20140422_1945Z_crs_gauss.nc
# 20140422_2000Z_crs_gauss.nc
# 20140422_2015Z_crs_gauss.nc
# 20140422_2030Z_crs_gauss.nc
# 20140422_2100Z_crs_gauss.nc
# 20140422_2130Z_crs_gauss.nc
# 20140422_2145Z_crs_gauss.nc
# 20140422_2200Z_crs_gauss.nc
# 20140422_2215Z_crs_gauss.nc
# 20140422_2230Z_crs_gauss.nc
# 20140425_1630Z_crs_gauss.nc
# 20140425_1645Z_crs_gauss.nc
# 20140425_1700Z_crs_gauss.nc
# 20140425_1715Z_crs_gauss.nc
# 20140425_1730Z_crs_gauss.nc
# 20140425_1745Z_crs_gauss.nc
# 20140425_1800Z_crs_gauss.nc
# 20140425_1830Z_crs_gauss.nc
# 20140425_1845Z_crs_gauss.nc
# 20140425_1900Z_crs_gauss.nc
# 20140425_1915Z_crs_gauss.nc
# 20140425_1930Z_crs_gauss.nc
# 20140425_1945Z_crs_gauss.nc
# 20140425_2000Z_crs_gauss.nc
# 20140425_2015Z_crs_gauss.nc
# 20140425_2030Z_crs_gauss.nc
# 20140425_2100Z_crs_gauss.nc
# 20140425_2130Z_crs_gauss.nc
# 20140425_2145Z_crs_gauss.nc
# 20140425_2200Z_crs_gauss.nc
# 20140425_2215Z_crs_gauss.nc
# 20140425_2230Z_crs_gauss.nc
# 20140426_1630Z_crs_gauss.nc
# 20140426_1645Z_crs_gauss.nc
# 20140426_1700Z_crs_gauss.nc
# 20140426_1715Z_crs_gauss.nc
# 20140426_1730Z_crs_gauss.nc
# 20140426_1745Z_crs_gauss.nc
# 20140426_1800Z_crs_gauss.nc
# 20140426_1830Z_crs_gauss.nc
# 20140426_1845Z_crs_gauss.nc
# 20140426_1900Z_crs_gauss.nc
# 20140426_1915Z_crs_gauss.nc
# 20140426_1930Z_crs_gauss.nc
# 20140426_1945Z_crs_gauss.nc
# 20140426_2000Z_crs_gauss.nc
# 20140426_2015Z_crs_gauss.nc
# 20140426_2030Z_crs_gauss.nc
# 20140426_2100Z_crs_gauss.nc
# 20140426_2130Z_crs_gauss.nc
# 20140426_2145Z_crs_gauss.nc
# 20140426_2200Z_crs_gauss.nc
# 20140426_2215Z_crs_gauss.nc
# 20140426_2230Z_crs_gauss.nc
# 20140505_1630Z_crs_gauss.nc
# 20140505_1645Z_crs_gauss.nc
# 20140505_1700Z_crs_gauss.nc
# 20140505_1715Z_crs_gauss.nc
# 20140505_1730Z_crs_gauss.nc
# 20140505_1745Z_crs_gauss.nc
# 20140505_1800Z_crs_gauss.nc
# 20140505_1830Z_crs_gauss.nc
# 20140505_1845Z_crs_gauss.nc
# 20140505_1900Z_crs_gauss.nc
# 20140505_1915Z_crs_gauss.nc
# 20140505_1930Z_crs_gauss.nc
# 20140505_1945Z_crs_gauss.nc
# 20140505_2000Z_crs_gauss.nc
# 20140505_2015Z_crs_gauss.nc
# 20140505_2030Z_crs_gauss.nc
# 20140505_2100Z_crs_gauss.nc
# 20140505_2130Z_crs_gauss.nc
# 20140505_2145Z_crs_gauss.nc
# 20140505_2200Z_crs_gauss.nc
# 20140505_2215Z_crs_gauss.nc
# 20140505_2230Z_crs_gauss.nc
# 20140506_1630Z_crs_gauss.nc
# 20140506_1645Z_crs_gauss.nc
# 20140506_1700Z_crs_gauss.nc
# 20140506_1715Z_crs_gauss.nc
# 20140506_1730Z_crs_gauss.nc
# 20140506_1745Z_crs_gauss.nc
# 20140506_1830Z_crs_gauss.nc
# 20140506_1845Z_crs_gauss.nc
# 20140506_1900Z_crs_gauss.nc
# 20140506_1915Z_crs_gauss.nc
# 20140506_1930Z_crs_gauss.nc
# 20140506_1945Z_crs_gauss.nc
# 20140506_2000Z_crs_gauss.nc
# 20140506_2015Z_crs_gauss.nc
# 20140506_2030Z_crs_gauss.nc
# 20140506_2100Z_crs_gauss.nc
# 20140506_2130Z_crs_gauss.nc
# 20140506_2145Z_crs_gauss.nc
# 20140506_2200Z_crs_gauss.nc
# 20140506_2215Z_crs_gauss.nc
# 20140506_2230Z_crs_gauss.nc
# 20140507_1630Z_crs_gauss.nc
# 20140507_1700Z_crs_gauss.nc
# 20140507_1715Z_crs_gauss.nc
# 20140507_1730Z_crs_gauss.nc
# 20140507_1745Z_crs_gauss.nc
# 20140507_1800Z_crs_gauss.nc
# 20140507_1830Z_crs_gauss.nc
# 20140507_1845Z_crs_gauss.nc
# 20140507_1900Z_crs_gauss.nc
# 20140507_1915Z_crs_gauss.nc
# 20140507_1930Z_crs_gauss.nc
# 20140507_1945Z_crs_gauss.nc
# 20140507_2000Z_crs_gauss.nc
# 20140507_2015Z_crs_gauss.nc
# 20140507_2030Z_crs_gauss.nc
# 20140507_2130Z_crs_gauss.nc
# 20140507_2145Z_crs_gauss.nc
# 20140507_2200Z_crs_gauss.nc
# 20140507_2215Z_crs_gauss.nc
# 20140507_2230Z_crs_gauss.nc
# 20140508_1630Z_crs_gauss.nc
# 20140508_1645Z_crs_gauss.nc
# 20140508_1700Z_crs_gauss.nc
# 20140508_1715Z_crs_gauss.nc
# 20140508_1730Z_crs_gauss.nc
# 20140508_1800Z_crs_gauss.nc
# 20140508_1830Z_crs_gauss.nc
# 20140508_1845Z_crs_gauss.nc
# 20140508_1900Z_crs_gauss.nc
# 20140508_1915Z_crs_gauss.nc
# 20140508_1930Z_crs_gauss.nc
# 20140508_1945Z_crs_gauss.nc
# 20140508_2015Z_crs_gauss.nc
# 20140508_2030Z_crs_gauss.nc
# 20140508_2100Z_crs_gauss.nc
# 20140508_2130Z_crs_gauss.nc
# 20140508_2145Z_crs_gauss.nc
# 20140508_2200Z_crs_gauss.nc
# 20140508_2215Z_crs_gauss.nc
# 20140508_2230Z_crs_gauss.nc
# 20140509_1630Z_crs_gauss.nc
# 20140509_1645Z_crs_gauss.nc
# 20140509_1700Z_crs_gauss.nc
# 20140509_1715Z_crs_gauss.nc
# 20140509_1730Z_crs_gauss.nc
# 20140509_1745Z_crs_gauss.nc
# 20140509_1800Z_crs_gauss.nc
# 20140509_1830Z_crs_gauss.nc
# 20140509_1845Z_crs_gauss.nc
# 20140509_1900Z_crs_gauss.nc
# 20140509_1915Z_crs_gauss.nc
# 20140509_1930Z_crs_gauss.nc
# 20140509_1945Z_crs_gauss.nc
# 20140509_2000Z_crs_gauss.nc
# 20140509_2015Z_crs_gauss.nc
# 20140509_2030Z_crs_gauss.nc
# 20140509_2100Z_crs_gauss.nc
# 20140509_2130Z_crs_gauss.nc
# 20140509_2145Z_crs_gauss.nc
# 20140509_2200Z_crs_gauss.nc
# 20140509_2215Z_crs_gauss.nc
# 20140509_2230Z_crs_gauss.nc
# 20140519_1630Z_crs_gauss.nc
# 20140519_1645Z_crs_gauss.nc
# 20140519_1700Z_crs_gauss.nc
# 20140519_1715Z_crs_gauss.nc
# 20140519_1745Z_crs_gauss.nc
# 20140519_1800Z_crs_gauss.nc
# 20140519_1830Z_crs_gauss.nc
# 20140519_1900Z_crs_gauss.nc
# 20140519_1915Z_crs_gauss.nc
# 20140519_1930Z_crs_gauss.nc
# 20140519_1945Z_crs_gauss.nc
# 20140519_2000Z_crs_gauss.nc
# 20140519_2015Z_crs_gauss.nc
# 20140519_2030Z_crs_gauss.nc
# 20140519_2100Z_crs_gauss.nc
# 20140519_2130Z_crs_gauss.nc
# 20140519_2145Z_crs_gauss.nc
# 20140519_2200Z_crs_gauss.nc
# 20140519_2215Z_crs_gauss.nc
# 20140519_2230Z_crs_gauss.nc
# 20140520_1630Z_crs_gauss.nc
# 20140520_1700Z_crs_gauss.nc
# 20140520_1715Z_crs_gauss.nc
# 20140520_1730Z_crs_gauss.nc
# 20140520_1745Z_crs_gauss.nc
# 20140520_1800Z_crs_gauss.nc
# 20140520_1830Z_crs_gauss.nc
# 20140520_1845Z_crs_gauss.nc
# 20140520_1900Z_crs_gauss.nc
# 20140520_1915Z_crs_gauss.nc
# 20140520_1930Z_crs_gauss.nc
# 20140520_1945Z_crs_gauss.nc
# 20140520_2000Z_crs_gauss.nc
# 20140520_2015Z_crs_gauss.nc
# 20140520_2030Z_crs_gauss.nc
# 20140520_2100Z_crs_gauss.nc
# 20140520_2130Z_crs_gauss.nc
# 20140520_2145Z_crs_gauss.nc
# 20140520_2200Z_crs_gauss.nc
# 20140520_2215Z_crs_gauss.nc
# 20140520_2230Z_crs_gauss.nc
# 20140521_1630Z_crs_gauss.nc
# 20140521_1645Z_crs_gauss.nc
# 20140521_1700Z_crs_gauss.nc
# 20140521_1715Z_crs_gauss.nc
# 20140521_1730Z_crs_gauss.nc
# 20140521_1745Z_crs_gauss.nc
# 20140521_1800Z_crs_gauss.nc
# 20140521_1830Z_crs_gauss.nc
# 20140521_1845Z_crs_gauss.nc
# 20140521_1900Z_crs_gauss.nc
# 20140521_1915Z_crs_gauss.nc
# 20140521_1930Z_crs_gauss.nc
# 20140521_1945Z_crs_gauss.nc
# 20140521_2000Z_crs_gauss.nc
# 20140521_2015Z_crs_gauss.nc
# 20140521_2030Z_crs_gauss.nc
# 20140521_2100Z_crs_gauss.nc
# 20140521_2130Z_crs_gauss.nc
# 20140521_2145Z_crs_gauss.nc
# 20140521_2200Z_crs_gauss.nc
# 20140521_2215Z_crs_gauss.nc
# 20140521_2230Z_crs_gauss.nc
# 20140522_1630Z_crs_gauss.nc
# 20140522_1645Z_crs_gauss.nc
# 20140522_1700Z_crs_gauss.nc
# 20140522_1715Z_crs_gauss.nc
# 20140522_1745Z_crs_gauss.nc
# 20140522_1800Z_crs_gauss.nc
# 20140522_1845Z_crs_gauss.nc
# 20140522_1900Z_crs_gauss.nc
# 20140522_1915Z_crs_gauss.nc
# 20140522_1930Z_crs_gauss.nc
# 20140522_1945Z_crs_gauss.nc
# 20140522_2015Z_crs_gauss.nc
# 20140522_2030Z_crs_gauss.nc
# 20140522_2100Z_crs_gauss.nc
# 20140522_2130Z_crs_gauss.nc
# 20140522_2145Z_crs_gauss.nc
# 20140522_2200Z_crs_gauss.nc
# 20140522_2215Z_crs_gauss.nc
# 20140522_2230Z_crs_gauss.nc
# 20140523_1630Z_crs_gauss.nc
# 20140523_1645Z_crs_gauss.nc
# 20140523_1700Z_crs_gauss.nc
# 20140523_1715Z_crs_gauss.nc
# 20140523_1730Z_crs_gauss.nc
# 20140523_1745Z_crs_gauss.nc
# 20140523_1800Z_crs_gauss.nc
# 20140523_1830Z_crs_gauss.nc
# 20140523_1845Z_crs_gauss.nc
# 20140523_1900Z_crs_gauss.nc
# 20140523_1915Z_crs_gauss.nc
# 20140523_1930Z_crs_gauss.nc
# 20140523_1945Z_crs_gauss.nc
# 20140523_2000Z_crs_gauss.nc
# 20140523_2030Z_crs_gauss.nc
# 20140523_2100Z_crs_gauss.nc
# 20140523_2130Z_crs_gauss.nc
# 20140523_2145Z_crs_gauss.nc
# 20140523_2200Z_crs_gauss.nc
# 20140523_2215Z_crs_gauss.nc
# 20140523_2230Z_crs_gauss.nc
# 20140524_1630Z_crs_gauss.nc
# 20140524_1645Z_crs_gauss.nc
# 20140524_1700Z_crs_gauss.nc
# 20140524_1715Z_crs_gauss.nc
# 20140524_1730Z_crs_gauss.nc
# 20140524_1745Z_crs_gauss.nc
# 20140524_1800Z_crs_gauss.nc
# 20140524_1845Z_crs_gauss.nc
# 20140524_1900Z_crs_gauss.nc
# 20140524_1915Z_crs_gauss.nc
# 20140524_1930Z_crs_gauss.nc
# 20140524_1945Z_crs_gauss.nc
# 20140524_2000Z_crs_gauss.nc
# 20140524_2015Z_crs_gauss.nc
# 20140524_2030Z_crs_gauss.nc
# 20140524_2100Z_crs_gauss.nc
# 20140524_2130Z_crs_gauss.nc
# 20140524_2145Z_crs_gauss.nc
# 20140524_2200Z_crs_gauss.nc
# 20140524_2215Z_crs_gauss.nc
# 20140524_2230Z_crs_gauss.nc
# 20140525_1630Z_crs_gauss.nc
# 20140525_1645Z_crs_gauss.nc
# 20140525_1700Z_crs_gauss.nc
# 20140525_1715Z_crs_gauss.nc
# 20140525_1730Z_crs_gauss.nc
# 20140525_1745Z_crs_gauss.nc
# 20140525_1800Z_crs_gauss.nc
# 20140525_1830Z_crs_gauss.nc
# 20140525_1845Z_crs_gauss.nc
# 20140525_1900Z_crs_gauss.nc
# 20140525_1915Z_crs_gauss.nc
# 20140525_1930Z_crs_gauss.nc
# 20140525_1945Z_crs_gauss.nc
# 20140525_2000Z_crs_gauss.nc
# 20140525_2015Z_crs_gauss.nc
# 20140525_2030Z_crs_gauss.nc
# 20140525_2100Z_crs_gauss.nc
# 20140525_2130Z_crs_gauss.nc
# 20140525_2145Z_crs_gauss.nc
# 20140525_2200Z_crs_gauss.nc
# 20140525_2215Z_crs_gauss.nc
# 20140525_2230Z_crs_gauss.nc
# 20140529_1630Z_crs_gauss.nc
# 20140529_1645Z_crs_gauss.nc
# 20140529_1700Z_crs_gauss.nc
# 20140529_1715Z_crs_gauss.nc
# 20140529_1730Z_crs_gauss.nc
# 20140529_1745Z_crs_gauss.nc
# 20140529_1800Z_crs_gauss.nc
# 20140529_1830Z_crs_gauss.nc
# 20140529_1845Z_crs_gauss.nc
# 20140529_1900Z_crs_gauss.nc
# 20140529_1915Z_crs_gauss.nc
# 20140529_1930Z_crs_gauss.nc
# 20140529_1945Z_crs_gauss.nc
# 20140529_2015Z_crs_gauss.nc
# 20140529_2030Z_crs_gauss.nc
# 20140529_2100Z_crs_gauss.nc
# 20140529_2130Z_crs_gauss.nc
# 20140529_2145Z_crs_gauss.nc
# 20140529_2200Z_crs_gauss.nc
# 20140529_2215Z_crs_gauss.nc
# 20140529_2230Z_crs_gauss.nc
# 20140530_1630Z_crs_gauss.nc
# 20140530_1645Z_crs_gauss.nc
# 20140530_1700Z_crs_gauss.nc
# 20140530_1715Z_crs_gauss.nc
# 20140530_1730Z_crs_gauss.nc
# 20140530_1745Z_crs_gauss.nc
# 20140530_1800Z_crs_gauss.nc
# 20140530_1830Z_crs_gauss.nc
# 20140530_1845Z_crs_gauss.nc
# 20140530_1900Z_crs_gauss.nc
# 20140530_1915Z_crs_gauss.nc
# 20140530_1930Z_crs_gauss.nc
# 20140530_1945Z_crs_gauss.nc
# 20140530_2000Z_crs_gauss.nc
# 20140530_2015Z_crs_gauss.nc
# 20140530_2030Z_crs_gauss.nc
# 20140530_2100Z_crs_gauss.nc
# 20140530_2130Z_crs_gauss.nc
# 20140530_2145Z_crs_gauss.nc
# 20140530_2200Z_crs_gauss.nc
# 20140530_2215Z_crs_gauss.nc
# 20140530_2230Z_crs_gauss.nc
# 20140603_1630Z_crs_gauss.nc
# 20140603_1645Z_crs_gauss.nc
# 20140603_1700Z_crs_gauss.nc
# 20140603_1715Z_crs_gauss.nc
# 20140603_1730Z_crs_gauss.nc
# 20140603_1745Z_crs_gauss.nc
# 20140603_1800Z_crs_gauss.nc
# 20140603_1830Z_crs_gauss.nc
# 20140603_1845Z_crs_gauss.nc
# 20140603_1900Z_crs_gauss.nc
# 20140603_1915Z_crs_gauss.nc
# 20140603_1930Z_crs_gauss.nc
# 20140603_1945Z_crs_gauss.nc
# 20140603_2000Z_crs_gauss.nc
# 20140603_2015Z_crs_gauss.nc
# 20140603_2030Z_crs_gauss.nc
# 20140603_2100Z_crs_gauss.nc
# 20140603_2130Z_crs_gauss.nc
# 20140603_2145Z_crs_gauss.nc
# 20140603_2200Z_crs_gauss.nc
# 20140603_2215Z_crs_gauss.nc
# 20140603_2230Z_crs_gauss.nc
# 20140610_1630Z_crs_gauss.nc
# 20140610_1645Z_crs_gauss.nc
# 20140610_1700Z_crs_gauss.nc
# 20140610_1715Z_crs_gauss.nc
# 20140610_1730Z_crs_gauss.nc
# 20140610_1745Z_crs_gauss.nc
# 20140610_1800Z_crs_gauss.nc
# 20140610_1830Z_crs_gauss.nc
# 20140610_1845Z_crs_gauss.nc
# 20140610_1900Z_crs_gauss.nc
# 20140610_1915Z_crs_gauss.nc
# 20140610_1930Z_crs_gauss.nc
# 20140610_1945Z_crs_gauss.nc
# 20140610_2000Z_crs_gauss.nc
# 20140610_2015Z_crs_gauss.nc
# 20140610_2030Z_crs_gauss.nc
# 20140610_2100Z_crs_gauss.nc
# 20140610_2130Z_crs_gauss.nc
# 20140610_2145Z_crs_gauss.nc
# 20140610_2200Z_crs_gauss.nc
# 20140610_2215Z_crs_gauss.nc
# 20140610_2230Z_crs_gauss.nc
# 20140611_1630Z_crs_gauss.nc
# 20140611_1645Z_crs_gauss.nc
# 20140611_1700Z_crs_gauss.nc
# 20140611_1715Z_crs_gauss.nc
# 20140611_1730Z_crs_gauss.nc
# 20140611_1745Z_crs_gauss.nc
# 20140611_1800Z_crs_gauss.nc
# 20140611_1830Z_crs_gauss.nc
# 20140611_1845Z_crs_gauss.nc
# 20140611_1900Z_crs_gauss.nc
# 20140611_1915Z_crs_gauss.nc
# 20140611_1930Z_crs_gauss.nc
# 20140611_1945Z_crs_gauss.nc
# 20140611_2000Z_crs_gauss.nc
# 20140611_2015Z_crs_gauss.nc
# 20140611_2030Z_crs_gauss.nc
# 20140611_2100Z_crs_gauss.nc
# 20140611_2130Z_crs_gauss.nc
# 20140611_2145Z_crs_gauss.nc
# 20140611_2200Z_crs_gauss.nc
# 20140611_2215Z_crs_gauss.nc
# 20140611_2230Z_crs_gauss.nc
# 20140612_1630Z_crs_gauss.nc
# 20140612_1645Z_crs_gauss.nc
# 20140612_1700Z_crs_gauss.nc
# 20140612_1715Z_crs_gauss.nc
# 20140612_1730Z_crs_gauss.nc
# 20140612_1745Z_crs_gauss.nc
# 20140612_1800Z_crs_gauss.nc
# 20140612_1830Z_crs_gauss.nc
# 20140612_1845Z_crs_gauss.nc
# 20140612_1900Z_crs_gauss.nc
# 20140612_1915Z_crs_gauss.nc
# 20140612_1930Z_crs_gauss.nc
# 20140612_1945Z_crs_gauss.nc
# 20140612_2015Z_crs_gauss.nc
# 20140612_2030Z_crs_gauss.nc
# 20140612_2100Z_crs_gauss.nc
# 20140612_2130Z_crs_gauss.nc
# 20140612_2145Z_crs_gauss.nc
# 20140612_2200Z_crs_gauss.nc
# 20140612_2215Z_crs_gauss.nc
# 20140612_2230Z_crs_gauss.nc
# 20140614_1630Z_crs_gauss.nc
# 20140614_1645Z_crs_gauss.nc
# 20140614_1700Z_crs_gauss.nc
# 20140614_1715Z_crs_gauss.nc
# 20140614_1730Z_crs_gauss.nc
# 20140614_1745Z_crs_gauss.nc
# 20140614_1800Z_crs_gauss.nc
# 20140614_1830Z_crs_gauss.nc
# 20140614_1845Z_crs_gauss.nc
# 20140614_1900Z_crs_gauss.nc
# 20140614_1915Z_crs_gauss.nc
# 20140614_1930Z_crs_gauss.nc
# 20140614_1945Z_crs_gauss.nc
# 20140614_2000Z_crs_gauss.nc
# 20140614_2015Z_crs_gauss.nc
# 20140614_2030Z_crs_gauss.nc
# 20140614_2100Z_crs_gauss.nc
# 20140614_2130Z_crs_gauss.nc
# 20140614_2145Z_crs_gauss.nc
# 20140614_2200Z_crs_gauss.nc
# 20140614_2215Z_crs_gauss.nc
# 20140614_2230Z_crs_gauss.nc
# 20140615_1630Z_crs_gauss.nc
# 20140615_1645Z_crs_gauss.nc
# 20140615_1700Z_crs_gauss.nc
# 20140615_1715Z_crs_gauss.nc
# 20140615_1730Z_crs_gauss.nc
# 20140615_1745Z_crs_gauss.nc
# 20140615_1800Z_crs_gauss.nc
# 20140615_1830Z_crs_gauss.nc
# 20140615_1845Z_crs_gauss.nc
# 20140615_1900Z_crs_gauss.nc
# 20140615_1915Z_crs_gauss.nc
# 20140615_1930Z_crs_gauss.nc
# 20140615_1945Z_crs_gauss.nc
# 20140615_2000Z_crs_gauss.nc
# 20140615_2015Z_crs_gauss.nc
# 20140615_2030Z_crs_gauss.nc
# 20140615_2100Z_crs_gauss.nc
# 20140615_2130Z_crs_gauss.nc
# 20140615_2145Z_crs_gauss.nc
# 20140615_2200Z_crs_gauss.nc
# 20140615_2215Z_crs_gauss.nc
# 20140615_2230Z_crs_gauss.nc
# 20140616_1630Z_crs_gauss.nc
# 20140616_1645Z_crs_gauss.nc
# 20140616_1700Z_crs_gauss.nc
# 20140616_1715Z_crs_gauss.nc
# 20140616_1730Z_crs_gauss.nc
# 20140616_1745Z_crs_gauss.nc
# 20140616_1800Z_crs_gauss.nc
# 20140616_1830Z_crs_gauss.nc
# 20140616_1845Z_crs_gauss.nc
# 20140616_1900Z_crs_gauss.nc
# 20140616_1915Z_crs_gauss.nc
# 20140616_1930Z_crs_gauss.nc
# 20140616_1945Z_crs_gauss.nc
# 20140616_2000Z_crs_gauss.nc
# 20140616_2015Z_crs_gauss.nc
# 20140616_2030Z_crs_gauss.nc
# 20140616_2100Z_crs_gauss.nc
# 20140616_2130Z_crs_gauss.nc
# 20140616_2145Z_crs_gauss.nc
# 20140616_2200Z_crs_gauss.nc
# 20140616_2215Z_crs_gauss.nc
# 20140616_2230Z_crs_gauss.nc
# 20140617_1630Z_crs_gauss.nc
# 20140617_1645Z_crs_gauss.nc
# 20140617_1700Z_crs_gauss.nc
# 20140617_1715Z_crs_gauss.nc
# 20140617_1730Z_crs_gauss.nc
# 20140617_1745Z_crs_gauss.nc
# 20140617_1800Z_crs_gauss.nc
# 20140617_1830Z_crs_gauss.nc
# 20140617_1845Z_crs_gauss.nc
# 20140617_1900Z_crs_gauss.nc
# 20140617_1915Z_crs_gauss.nc
# 20140617_1930Z_crs_gauss.nc
# 20140617_1945Z_crs_gauss.nc
# 20140617_2000Z_crs_gauss.nc
# 20140617_2015Z_crs_gauss.nc
# 20140617_2030Z_crs_gauss.nc
# 20140617_2100Z_crs_gauss.nc
# 20140617_2130Z_crs_gauss.nc
# 20140617_2145Z_crs_gauss.nc
# 20140617_2200Z_crs_gauss.nc
# 20140617_2215Z_crs_gauss.nc
# 20140618_1630Z_crs_gauss.nc
# 20140618_1645Z_crs_gauss.nc
# 20140618_1700Z_crs_gauss.nc
# 20140618_1715Z_crs_gauss.nc
# 20140618_1730Z_crs_gauss.nc
# 20140618_1745Z_crs_gauss.nc
# 20140618_1800Z_crs_gauss.nc
# 20140618_1830Z_crs_gauss.nc
# 20140618_1845Z_crs_gauss.nc
# 20140618_1900Z_crs_gauss.nc
# 20140618_1915Z_crs_gauss.nc
# 20140618_1930Z_crs_gauss.nc
# 20140618_1945Z_crs_gauss.nc
# 20140618_2000Z_crs_gauss.nc
# 20140618_2015Z_crs_gauss.nc
# 20140618_2030Z_crs_gauss.nc
# 20140618_2100Z_crs_gauss.nc
# 20140618_2130Z_crs_gauss.nc
# 20140618_2145Z_crs_gauss.nc
# 20140618_2200Z_crs_gauss.nc
# 20140618_2215Z_crs_gauss.nc
# 20140618_2230Z_crs_gauss.nc
# 20140619_1630Z_crs_gauss.nc
# 20140619_1645Z_crs_gauss.nc
# 20140619_1700Z_crs_gauss.nc
# 20140619_1715Z_crs_gauss.nc
# 20140619_1730Z_crs_gauss.nc
# 20140619_1745Z_crs_gauss.nc
# 20140619_1800Z_crs_gauss.nc
# 20140619_1830Z_crs_gauss.nc
# 20140619_1845Z_crs_gauss.nc
# 20140619_1900Z_crs_gauss.nc
# 20140619_1915Z_crs_gauss.nc
# 20140619_1930Z_crs_gauss.nc
# 20140619_1945Z_crs_gauss.nc
# 20140619_2015Z_crs_gauss.nc
# 20140619_2030Z_crs_gauss.nc
# 20140619_2100Z_crs_gauss.nc
# 20140619_2130Z_crs_gauss.nc
# 20140619_2145Z_crs_gauss.nc
# 20140619_2200Z_crs_gauss.nc
# 20140619_2215Z_crs_gauss.nc
# 20140619_2230Z_crs_gauss.nc
# 20140622_1630Z_crs_gauss.nc
# 20140622_1645Z_crs_gauss.nc
# 20140622_1700Z_crs_gauss.nc
# 20140622_1715Z_crs_gauss.nc
# 20140622_1730Z_crs_gauss.nc
# 20140622_1745Z_crs_gauss.nc
# 20140622_1800Z_crs_gauss.nc
# 20140622_1830Z_crs_gauss.nc
# 20140622_1845Z_crs_gauss.nc
# 20140622_1900Z_crs_gauss.nc
# 20140622_1915Z_crs_gauss.nc
# 20140622_1930Z_crs_gauss.nc
# 20140622_1945Z_crs_gauss.nc
# 20140622_2000Z_crs_gauss.nc
# 20140622_2015Z_crs_gauss.nc
# 20140622_2030Z_crs_gauss.nc
# 20140622_2100Z_crs_gauss.nc
# 20140622_2130Z_crs_gauss.nc
# 20140622_2145Z_crs_gauss.nc
# 20140622_2200Z_crs_gauss.nc
# 20140622_2215Z_crs_gauss.nc
# 20140622_2230Z_crs_gauss.nc

# %%
data
# Out:
#                                0
# 2014-04-02 16:30:00    0.0238193
# 2014-04-02 16:45:00    0.0230956
# 2014-04-02 17:00:00    0.0243916
# 2014-04-02 17:15:00    0.0257109
# 2014-04-02 17:30:00    0.0305533
# 2014-04-02 17:45:00    0.0374424
# 2014-04-02 18:00:00    0.0575738
# 2014-04-02 18:30:00    0.0679218
# 2014-04-02 18:45:00    0.0872591
# 2014-04-02 19:00:00     0.162451
# 2014-04-02 19:15:00     0.183034
# 2014-04-02 19:30:00      0.16886
# 2014-04-02 19:45:00     0.117527
# 2014-04-02 20:00:00     0.098093
# 2014-04-02 20:15:00     0.156118
# 2014-04-02 20:30:00     0.215038
# 2014-04-02 21:00:00    0.0773477
# 2014-04-02 21:30:00    0.0775642
# 2014-04-02 21:45:00    0.0742111
# 2014-04-02 22:00:00    0.0712355
# 2014-04-02 22:15:00    0.0678592
# 2014-04-02 22:30:00    0.0623274
# 2014-04-05 16:30:00    0.0198841
# 2014-04-05 16:45:00    0.0182879
# 2014-04-05 17:00:00    0.0190122
# 2014-04-05 17:15:00    0.0184849
# 2014-04-05 17:30:00    0.0179608
# 2014-04-05 17:45:00    0.0205671
# 2014-04-05 18:00:00    0.0222682
# 2014-04-05 18:30:00     0.028961
# ...                          ...
# 2014-06-19 20:15:00    0.0119497
# 2014-06-19 20:30:00     0.019658
# 2014-06-19 21:00:00    0.0151227
# 2014-06-19 21:30:00    0.0140018
# 2014-06-19 21:45:00   0.00729084
# 2014-06-19 22:00:00   0.00564525
# 2014-06-19 22:15:00   0.00220965
# 2014-06-19 22:30:00            0
# 2014-06-22 16:30:00  5.38203e-05
# 2014-06-22 16:45:00            0
# 2014-06-22 17:00:00            0
# 2014-06-22 17:15:00            0
# 2014-06-22 17:30:00            0
# 2014-06-22 17:45:00            0
# 2014-06-22 18:00:00            0
# 2014-06-22 18:30:00            0
# 2014-06-22 18:45:00            0
# 2014-06-22 19:00:00            0
# 2014-06-22 19:15:00            0
# 2014-06-22 19:30:00            0
# 2014-06-22 19:45:00            0
# 2014-06-22 20:00:00            0
# 2014-06-22 20:15:00            0
# 2014-06-22 20:30:00            0
# 2014-06-22 21:00:00            0
# 2014-06-22 21:30:00            0
# 2014-06-22 21:45:00            0
# 2014-06-22 22:00:00            0
# 2014-06-22 22:15:00            0
# 2014-06-22 22:30:00            0
#
# [840 rows x 1 columns]

# %%
data_sol = pd.DataFrame(index=data.index,columns=[0])
for t in data.index:
    weighted = np.multiply(data.loc[t].values,weights)
    avg = np.sum(weighted)/np.sum(weights)
    if(avg<0): avg=0
    data_sol.at[t]=avg
fr = [fr15,fr30,fr45,fr60]
data = data_sol

# %%
index_dates = data.index.date
index_dates_unique = np.unique(index_dates)
index_times = data.index
bs15 = pd.DataFrame(index=index_dates_unique,columns=data.columns)
bs30 = pd.DataFrame(index=index_dates_unique,columns=data.columns)
bs45 = pd.DataFrame(index=index_dates_unique,columns=data.columns)
bs60 = pd.DataFrame(index=index_dates_unique,columns=data.columns)
bs = [bs15,bs30,bs45,bs60]

data_bin = data.mask(data<thresh,other=1)
data_bin = data_bin.mask(data_bin!=1.0,other=0)

for c in data.columns:
    for d in index_dates_unique:
        times = index_times[np.where(index_dates==d)]
        sat = data_bin.loc[times,[c]]
        for f in range(4):
            frac = fr[f].loc[times,[c]]
            bs_vals = ((frac-sat)**2).values[:,0].astype(np.float)
            valid = np.where(np.invert(np.isnan(bs_vals)))
            bs[f].at[d,c] = np.sum(bs_vals[valid])/len(bs_vals[valid])
            
dec15 = pd.DataFrame(index=index_dates_unique,columns=['rel','res','sig','bs'])
dec30 = pd.DataFrame(index=index_dates_unique,columns=['rel','res','sig','bs'])
dec45 = pd.DataFrame(index=index_dates_unique,columns=['rel','res','sig','bs'])
dec60 = pd.DataFrame(index=index_dates_unique,columns=['rel','res','sig','bs'])
dec = [dec15,dec30,dec45,dec60]

c=0
for d in index_dates_unique:
    times = index_times[np.where(index_dates==d)]
    sat = data_bin.loc[times,[c]]
    for f in range(4):
        frac = fr[f].loc[times,[c]]
        bs_vals = ((frac-sat)**2).values[:,0].astype(np.float)
        sat_vals = sat.values[:,0].astype(np.float)
        frac_vals = frac.values[:,0].astype(np.float)
        valid = np.where(np.invert(np.isnan(bs_vals)))
        bs_valid = bs_vals[valid]
        sat_valid = sat_vals[valid]
        frac_valid = frac_vals[valid]
        
        unique,counts = np.unique(frac_valid,return_counts=True)
        n = np.sum(counts)
        obar_i = np.zeros(len(unique))
        for j in range(len(unique)):
            y = unique[j]
            wh = np.where(frac_valid==y)
            obar_i[j] = np.sum(sat_valid[wh])/counts[j]
        obar = np.sum(sat_valid)/n

        sig = obar*(1-obar)
        rel = np.sum(np.multiply(counts,(unique-obar_i)**2))/n
        res = np.sum(np.multiply(counts,(obar_i-obar)**2))/n
        dec[f].at[d,'rel'] = rel
        dec[f].at[d,'res'] = res
        dec[f].at[d,'sig'] = sig
        dec[f].at[d,'bs'] = rel-res+sig

# %%
avg_ci = [0.07326633937050787, 0.20778712302975885, 0.11192718638706237, 0.06896607381887883, 0.14332269534242617, 0.25472343970477335, 0.04777688933358877, 0.8596485152665307, 0.19564074560864855, 0.06170793115020668, 0.021583633585999476, 0.03259704694624734, 0.03989605709146575, 0.5405269801579695, 0.013546266323385918, 0.06124534490048805, 0.05463109817092926, 0.03606780100144922, 0.0638700738320475, 0.03620355300317931, 0.04244338007354623, 0.009881199632866159, 0.033942529421483604, 0.009342719017178461, 0.05944429052055939, 0.10105394353402507, 0.6654091999523657, 0.0021613105745977136, 0.013400553711767014, 0.017006162006099224, 0.09350540001254598, 0.10001397910002892, 0.006636670686108557, 0.09580385996389294, 0.08552496468202024, 0.16219456934530282, 0.10637936657699525, 0.017298070474985355, 0.0015729371576519585]

# %%
plt.rcParams['figure.figsize'] = [12,12]
ymin= 0
ymax = 0.3
rows = 1; cols = 1;

x = list(dec15.index)
xpos = np.array(range(len(x)))+1
width = 0.15
dx = width/2

fig,ax = plt.subplots(rows,cols)
ax.set_ylim([ymin,ymax])
ax.set_xlim([0,len(xpos)+1])
ax.set_xticks(xpos)
ax.set_xticklabels(x,rotation='vertical')

ax.bar(xpos-3*dx,dec15.values[:,0],width=width,color='b',label='reliability')
ax.bar(xpos-dx,dec15.values[:,1],width=width,color='g',label='resolution')
ax.bar(xpos+dx,dec15.values[:,2],width=width,color='r',label='uncertainty')
ax.bar(xpos+3*dx,dec15.values[:,3],width=width,color='k',label='brier score')

for i in range(1,len(x)+1):
    alpha = 0.5*avg_ci[i-1]
    ax.fill_between(np.arange(i-0.5,i+0.501,0.1),0,0.3,facecolor='k',alpha=alpha)

ax.set_title("15 minutes")

#fig.autofmt_xdate()
fig.tight_layout()
fig.suptitle("Brier Score Timeseries",fontsize=16)
fig.subplots_adjust(top=0.92)
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [12,18]
ymin= 0
ymax = 0.4
rows = 4; cols = 1;
fig,ax = plt.subplots(rows,cols,sharex=True)
for r in range(rows):
    for c in range(cols):
        ax[r].set_ylim([ymin,ymax])
        ax[r].set_xlim([0,len(xpos)+1])
        ax[r].set_xticks(xpos)
        ax[r].set_xticklabels(x,rotation='vertical')
        
ax[0].bar(xpos-3*dx,dec15.values[:,0],width=width,color='b',label='reliability')
ax[0].bar(xpos-dx,dec15.values[:,1],width=width,color='g',label='resolution')
ax[0].bar(xpos+dx,dec15.values[:,2],width=width,color='r',label='uncertainty')
ax[0].bar(xpos+3*dx,dec15.values[:,3],width=width,color='k',label='brier score')

ax[1].bar(xpos-3*dx,dec30.values[:,0],width=width,color='b',label='reliability')
ax[1].bar(xpos-dx,dec30.values[:,1],width=width,color='g',label='resolution')
ax[1].bar(xpos+dx,dec30.values[:,2],width=width,color='r',label='uncertainty')
ax[1].bar(xpos+3*dx,dec30.values[:,3],width=width,color='k',label='brier score')

ax[2].bar(xpos-3*dx,dec45.values[:,0],width=width,color='b',label='reliability')
ax[2].bar(xpos-dx,dec45.values[:,1],width=width,color='g',label='resolution')
ax[2].bar(xpos+dx,dec45.values[:,2],width=width,color='r',label='uncertainty')
ax[2].bar(xpos+3*dx,dec45.values[:,3],width=width,color='k',label='brier score')

ax[3].bar(xpos-3*dx,dec60.values[:,0],width=width,color='b',label='reliability')
ax[3].bar(xpos-dx,dec60.values[:,1],width=width,color='g',label='resolution')
ax[3].bar(xpos+dx,dec60.values[:,2],width=width,color='r',label='uncertainty')
ax[3].bar(xpos+3*dx,dec60.values[:,3],width=width,color='k',label='brier score')

for a in range(4):
    for i in range(1,len(x)+1):
        alpha = 0.5*avg_ci[i-1]
        ax[a].fill_between(np.arange(i-0.5,i+0.501,0.1),0,0.6,facecolor='k',alpha=alpha)

ax[0].set_title("15 minutes")
ax[1].set_title("30 minutes")
ax[2].set_title("45 minutes")
ax[3].set_title("60 minutes")

ax[0].legend()

#fig.autofmt_xdate()
fig.tight_layout()
fig.suptitle("Brier Score Timeseries",fontsize=16)
fig.subplots_adjust(top=0.92)
plt.show()

# %%
c=0

index_dates = data.index.date
index_dates_unique = np.unique(index_dates)
index_times = data.index

data_bin = data.mask(data<thresh,other=1)
data_bin = data_bin.mask(data_bin!=1.0,other=0)

sat = data_bin.loc[:,[c]]
for f in range(4):
    frac = fr[f].loc[:,[c]]
    bs_df = ((frac-sat)**2)
    times = bs_df.index.values
    bs_vals = bs_df.values[:,0].astype(np.float)
    valid = np.where(np.invert(np.isnan(bs_vals)))
    bs_valid = bs_vals[valid]
    valid_times = times[valid]
    sat_vals = sat.loc[valid_times,[c]].values[:,0]
    obar = np.sum(sat_vals)/len(sat_vals)
    
    brier = np.sum(bs_valid)/len(bs_valid)
    print((f+1)*15,'minutes :',brier)
    #print('BS = ',brier)
    #print('obar = ',obar)
# Out:
# 15 minutes : 0.035414186423237425
# 30 minutes : 0.047392610045969244
# 45 minutes : 0.05118127982411321
# 60 minutes : 0.06117474045488696

# %%
coord = 0
ytrue = data_bin[0].values.astype(np.float)

yprob15 = fr15.loc[data_bin.index.values].values[:,coord].astype(np.float)
yprob30 = fr30.loc[data_bin.index.values].values[:,coord].astype(np.float)
yprob45 = fr45.loc[data_bin.index.values].values[:,coord].astype(np.float)
yprob60 = fr60.loc[data_bin.index.values].values[:,coord].astype(np.float)

valid15 = [i for i in range(len(yprob15)) if not np.isnan(yprob15[i])]
valid30 = [i for i in range(len(yprob30)) if not np.isnan(yprob30[i])]
valid45 = [i for i in range(len(yprob45)) if not np.isnan(yprob45[i])]
valid60 = [i for i in range(len(yprob60)) if not np.isnan(yprob60[i])]

ptrue15,ppred15 = calibration_curve(ytrue[valid15],yprob15[valid15])
ptrue30,ppred30 = calibration_curve(ytrue[valid30],yprob30[valid30])
ptrue45,ppred45 = calibration_curve(ytrue[valid45],yprob45[valid45])
ptrue60,ppred60 = calibration_curve(ytrue[valid60],yprob60[valid60])

# %%
plt.rcParams['figure.figsize'] = [9, 9]

obar = 0.84 # similar obar for all outlook times

xmin = 0
ymin = xmin
xmax = 1
ymax = xmax
x = [xmin,xmax]
y = [ymin,ymax]
nsy = [obar/2,(1+obar)/2]
rows = 2; cols = 2;
fig,axarr = plt.subplots(rows,cols)
for r in range(rows):
    for c in range(cols):
        axarr[r,c].set_aspect('equal','box')
        axarr[r,c].axis([xmin,xmax,ymin,ymax])
        axarr[r,c].plot(x,y,c='k',lw=1)
        axarr[r,c].set_xlabel("fraction predicted")
        axarr[r,c].set_ylabel("fraction of positives")
        axarr[r,c].axhline(obar,ls='--',c='k',lw=1)
        axarr[r,c].axvline(obar,ls='--',c='k',lw=1)
        axarr[r,c].plot(x,nsy,c='k',lw=1)
        axarr[r,c].fill_between([0,obar],0,[obar/2,obar],facecolor='k',alpha=0.1)
        axarr[r,c].fill_between([obar,1],[obar,(1+obar)/2],1,facecolor='k',alpha=0.1)

        
n = np.array([64,11,11,37,549])
err15 = 1.96*np.sqrt(ptrue15*(1-ptrue15)/n)
err30 = 1.96*np.sqrt(ptrue30*(1-ptrue30)/n)
err45 = 1.96*np.sqrt(ptrue45*(1-ptrue45)/n)
err60 = 1.96*np.sqrt(ptrue60*(1-ptrue60)/n)        
        
axarr[0,0].scatter(ppred15,ptrue15)
axarr[0,0].errorbar(ppred15,ptrue15,err15,capsize=5)
axarr[0,0].plot(ppred15,ptrue15)

axarr[0,1].scatter(ppred30,ptrue30)
axarr[0,1].errorbar(ppred30,ptrue30,err30,capsize=5)
axarr[0,1].plot(ppred30,ptrue30)

axarr[1,0].scatter(ppred45,ptrue45)
axarr[1,0].errorbar(ppred45,ptrue45,err45,capsize=5)
axarr[1,0].plot(ppred45,ptrue45)

axarr[1,1].scatter(ppred60,ptrue60)
axarr[1,1].errorbar(ppred60,ptrue60,err60,capsize=5)
axarr[1,1].plot(ppred60,ptrue60)

axarr[0,0].set_title("15 minutes")
axarr[0,1].set_title("30 minutes")
axarr[1,0].set_title("45 minutes")
axarr[1,1].set_title("60 minutes")

fig.tight_layout()
fig.suptitle("Reliability Curves",fontsize=16)
fig.subplots_adjust(top=0.92)
plt.show()

# %%
n = plt.hist(yprob15[valid15],bins=5)
plt.ylim([0,550])
plt.show()
print(n[0])
# Out:
# [ 62.  13.  29.  83. 485.]
